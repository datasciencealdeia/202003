# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=30)
model.evaluate(x_test, y_test)
# Out:
# Train on 60000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0414 - accuracy: 0.9862
# Epoch 2/30
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0398 - accuracy: 0.9865
# Epoch 3/30
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0365 - accuracy: 0.9875
# Epoch 4/30
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0340 - accuracy: 0.9884
# Epoch 5/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0310 - accuracy: 0.9893
# Epoch 6/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.0304 - accuracy: 0.9895
# Epoch 7/30
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.0285 - accuracy: 0.9906
# Epoch 8/30
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.0290 - accuracy: 0.9899
# Epoch 9/30
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0262 - accuracy: 0.9905
# Epoch 10/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0272 - accuracy: 0.9906
# Epoch 11/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.0253 - accuracy: 0.9909
# Epoch 12/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.0255 - accuracy: 0.9912
# Epoch 13/30
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0256 - accuracy: 0.9913
# Epoch 14/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0229 - accuracy: 0.9920
# Epoch 15/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0210 - accuracy: 0.9927
# Epoch 16/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0229 - accuracy: 0.9918
# Epoch 17/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.0203 - accuracy: 0.9930
# Epoch 18/30
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0209 - accuracy: 0.9927
# Epoch 19/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0212 - accuracy: 0.9926
# Epoch 20/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0201 - accuracy: 0.9934
# Epoch 21/30
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0190 - accuracy: 0.9932
# Epoch 22/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0207 - accuracy: 0.9927
# Epoch 23/30
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0189 - accuracy: 0.9933
# Epoch 24/30
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0186 - accuracy: 0.9935
# Epoch 25/30
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0191 - accuracy: 0.9934
# Epoch 26/30
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0190 - accuracy: 0.9929
# Epoch 27/30
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0173 - accuracy: 0.9940
# Epoch 28/30
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0176 - accuracy: 0.9938
# Epoch 29/30
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.0158 - accuracy: 0.9942
# Epoch 30/30
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.0183 - accuracy: 0.9938
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.10358016617180203, 0.9801]
